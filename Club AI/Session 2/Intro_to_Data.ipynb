# %%
import pandas as pd

# %%
df = pd.read_csv('/content/pakistan_intellectual_capital.csv')

# %%
df.head(2) # to show the first 2 lines
# Out:
#    Unnamed: 0  S#     Teacher Name University Currently Teaching  \
# 0           2   3  Dr. Abdul Basit     University of Balochistan
# 1           4   5  Dr. Waheed Noor     University of Balochistan
#
#               Department Province University Located          Designation  \
# 0  Computer Science & IT                 Balochistan  Assistant Professor
# 1  Computer Science & IT                 Balochistan  Assistant Professor
#
#   Terminal Degree                 Graduated from   Country  Year  \
# 0             PhD  Asian Institute of Technology  Thailand   NaN
# 1             PhD  Asian Institute of Technology  Thailand   NaN
#
#   Area of Specialization/Research Interests Other Information
# 0               Software Engineering & DBMS               NaN
# 1                                      DBMS               NaN

# %%
df.tail(7) # to show the last 7 lines
# Out:
#       Unnamed: 0    S#            Teacher Name University Currently Teaching  \
# 1135        1943  1944          Muhammad Yasir             Abasyn University
# 1136        1971  1972   Dr. Khalid J Siddiqui   Ghulam Ishaq Khan Institute
# 1137        1974  1975        Dr. Ahmar Rashid   Ghulam Ishaq Khan Institute
# 1138        1975  1976       Dr. Fawad Hussain   Ghulam Ishaq Khan Institute
# 1139        1977  1978    Dr. Rashad M Jillani   Ghulam Ishaq Khan Institute
# 1140        1979  1980  Dr. Shahabuddin Ansari   Ghulam Ishaq Khan Institute
# 1141        1980  1981         Dr. Sajid Anwar   Ghulam Ishaq Khan Institute
#
#                             Department Province University Located  \
# 1135                  Computer Science                         KPK
# 1136  Computer Science and Engineering                         KPK
# 1137  Computer Science and Engineering                         KPK
# 1138  Computer Science and Engineering                         KPK
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 1142 non-null   int64
#  1   S#                                         1142 non-null   int64
#  2   Teacher Name                               1142 non-null   object
#  3   University Currently Teaching              1142 non-null   object
#  4   Department                                 1142 non-null   object
#  5   Province University Located                1142 non-null   object
#  6   Designation                                1123 non-null   object
#  7   Terminal Degree                            1138 non-null   object
#  8   Graduated from                             1142 non-null   object
#  9   Country                                    1142 non-null   object
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0           S#         Year
# count  1142.000000  1142.000000   489.000000
# mean   1054.350263  1055.350263  2010.456033
# std     520.202783   520.202783     5.577565
# min       2.000000     3.000000  1983.000000
# 25%     689.250000   690.250000  2008.000000
# 50%    1087.500000  1088.500000  2012.000000
# 75%    1476.750000  1477.750000  2014.000000
# max    1980.000000  1981.000000  2018.000000

# %%
from google.colab import drive
drive.mount('/content/drive') # to mount google drive
